# %% [markdown]
# # Using UV ZO Unit Model

# %% [markdown]
# ## Step 1: Import the necessary functions

# %%
from pyomo.environ import ConcreteModel, Suffix, units as pyunits
from idaes.core import FlowsheetBlock
from watertap.core.zero_order_properties import WaterParameterBlock
from watertap.core.wt_database import Database
from watertap.unit_models.zero_order.uv_zo import UVZO
from idaes.core.util.model_statistics import degrees_of_freedom
from pyomo.environ import ConcreteModel, assert_optimal_termination
from pyomo.util.check_units import assert_units_consistent
from watertap.core.solvers import get_solver

# %% [markdown]
# ## Step 2: Create the ConcreteModel and FlowsheetBlock
# Create the flowsheet by attaching the property package and building the custom unit model.

# %%
m = ConcreteModel()
m.fs = FlowsheetBlock(dynamic=False)
# Attach property package
m.fs.db = Database('../watertap/data/techno_economic')
m.fs.properties = WaterParameterBlock(database=m.fs.db)
# Build the unit model
m.fs.unit = UVZO(property_package=m.fs.properties, database=m.fs.db)

# Display model
print(m.fs.unit.display())
# Out:
# Block fs.unit
#
#   Variables:
#     _flow_mass_comp_inlet_ref : Size=12, Index=fs._time*fs.properties.component_list, ReferenceTo=fs.unit.properties_in[...].component('flow_mass_comp')[...]
#         Key                : Lower : Value : Upper : Fixed : Stale : Domain
#               (0.0, 'H2O') :     0 :     1 :  None : False : False : PositiveReals
#             (0.0, 'boron') :     0 :     1 :  None : False : False : PositiveReals
#           (0.0, 'bromide') :     0 :     1 :  None : False : False : PositiveReals
#           (0.0, 'calcium') :     0 :     1 :  None : False : False : PositiveReals
#          (0.0, 'chloride') :     0 :     1 :  None : False : False : PositiveReals
#         (0.0, 'magnesium') :     0 :     1 :  None : False : False : PositiveReals
#         (0.0, 'potassium') :     0 :     1 :  None : False : False : PositiveReals
#            (0.0, 'sodium') :     0 :     1 :  None : False : False : PositiveReals
#         (0.0, 'strontium') :     0 :     1 :  None : False : False : PositiveReals
#           (0.0, 'sulfate') :     0 :     1 :  None : False : False : PositiveReals
#               (0.0, 'tds') :     0 :     1 :  None : False : False : PositiveReals
#               (0.0, 'tss') :     0 :     1 :  None : False : False : PositiveReals
#     _flow_mass_comp_treated_ref : Size=12, Index=fs._time*fs.properties.component_list, ReferenceTo=fs.unit.properties_treated[...].component('flow_mass_comp')[...]
#         Key                : Lower : Value : Upper : Fixed : Stale : Domain
#               (0.0, 'H2O') :     0 :     1 :  None : False : False : PositiveReals
#             (0.0, 'boron') :     0 :     1 :  None : False : False : PositiveReals
#           (0.0, 'bromide') :     0 :     1 :  None : False : False : PositiveReals
#           (0.0, 'calcium') :     0 :     1 :  None : False : False : PositiveReals
#          (0.0, 'chloride') :     0 :     1 :  None : False : False : PositiveReals
#         (0.0, 'magnesium') :     0 :     1 :  None : False : False : PositiveReals
#         (0.0, 'potassium') :     0 :     1 :  None : False : False : PositiveReals
#            (0.0, 'sodium') :     0 :     1 :  None : False : False : PositiveReals
#         (0.0, 'strontium') :     0 :     1 :  None : False : False : PositiveReals
#           (0.0, 'sulfate') :     0 :     1 :  None : False : False : PositiveReals
#               (0.0, 'tds') :     0 :     1 :  None : False : False : PositiveReals
#               (0.0, 'tss') :     0 :     1 :  None : False : False : PositiveReals
#     recovery_frac_mass_H2O : Mass recovery fraction of water in the treated stream
#         Size=1, Index=fs._time, Units=dimensionless
#         Key : Lower : Value : Upper     : Fixed : Stale : Domain
#         0.0 :   0.0 :     1 : 1.0000001 :  True : False : NonNegativeReals
#     removal_frac_mass_comp : Solute removal fraction on a mass basis
#         Size=11, Index=fs._time*fs.properties.solute_set, Units=dimensionless
#         Key                : Lower : Value : Upper : Fixed : Stale : Domain
#             (0.0, 'boron') :     0 :  0.01 :  None : False : False : NonNegativeReals
#           (0.0, 'bromide') :     0 :  0.01 :  None : False : False : NonNegativeReals
#           (0.0, 'calcium') :     0 :  0.01 :  None : False : False : NonNegativeReals
#          (0.0, 'chloride') :     0 :  0.01 :  None : False : False : NonNegativeReals
#         (0.0, 'magnesium') :     0 :  0.01 :  None : False : False : NonNegativeReals
#         (0.0, 'potassium') :     0 :  0.01 :  None : False : False : NonNegativeReals
#            (0.0, 'sodium') :     0 :  0.01 :  None : False : False : NonNegativeReals
#         (0.0, 'strontium') :     0 :  0.01 :  None : False : False : NonNegativeReals
#           (0.0, 'sulfate') :     0 :  0.01 :  None : False : False : NonNegativeReals
#               (0.0, 'tds') :     0 :  0.01 :  None : False : False : NonNegativeReals
#               (0.0, 'tss') :     0 :  0.01 :  None : False : False : NonNegativeReals
#     electricity : Electricity consumption of unit
#         Size=1, Index=fs._time, Units=kW
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :     0 :  None :  None : False :  True :  Reals
#     energy_electric_flow_vol_inlet : Electricity intensity with respect to inlet flowrate of unit
#         Size=1, Index=None, Units=kWh/m**3
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :  None :  None :  None : False :  True :  Reals
#     uv_reduced_equivalent_dose : Reduced equivalent dosage
#         Size=1, Index=fs._time, Units=mJ/cm**2
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :  None :  None :  None : False :  True :  Reals
#     uv_transmittance_in : UV transmittance of solution at UV reactor inlet
#         Size=1, Index=fs._time, Units=dimensionless
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :  None :  None :  None : False :  True :  Reals
#
#   Objectives:
#     None
#
#   Constraints:
#     water_recovery_equation : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :    0 :   0.0
#     solute_treated_equation : Size=11
#         Key                : Lower : Body                  : Upper
#             (0.0, 'boron') :   0.0 : -0.010000000000000009 :   0.0
#           (0.0, 'bromide') :   0.0 : -0.010000000000000009 :   0.0
#           (0.0, 'calcium') :   0.0 : -0.010000000000000009 :   0.0
#          (0.0, 'chloride') :   0.0 : -0.010000000000000009 :   0.0
#         (0.0, 'magnesium') :   0.0 : -0.010000000000000009 :   0.0
#         (0.0, 'potassium') :   0.0 : -0.010000000000000009 :   0.0
#            (0.0, 'sodium') :   0.0 : -0.010000000000000009 :   0.0
#         (0.0, 'strontium') :   0.0 : -0.010000000000000009 :   0.0
#           (0.0, 'sulfate') :   0.0 : -0.010000000000000009 :   0.0
#               (0.0, 'tds') :   0.0 : -0.010000000000000009 :   0.0
#               (0.0, 'tss') :   0.0 : -0.010000000000000009 :   0.0
#     electricity_consumption : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 : None :   0.0
#
#   Blocks:
#     Block fs.unit.properties_in[0.0]
#
#       Variables:
#         flow_mass_comp : Mass flowrate of each component
#             Size=12, Index=fs.properties.component_list, Units=kg/s
#             Key       : Lower : Value : Upper : Fixed : Stale : Domain
#                   H2O :     0 :     1 :  None : False : False : PositiveReals
#                 boron :     0 :     1 :  None : False : False : PositiveReals
#               bromide :     0 :     1 :  None : False : False : PositiveReals
#               calcium :     0 :     1 :  None : False : False : PositiveReals
#              chloride :     0 :     1 :  None : False : False : PositiveReals
#             magnesium :     0 :     1 :  None : False : False : PositiveReals
#             potassium :     0 :     1 :  None : False : False : PositiveReals
#                sodium :     0 :     1 :  None : False : False : PositiveReals
#             strontium :     0 :     1 :  None : False : False : PositiveReals
#               sulfate :     0 :     1 :  None : False : False : PositiveReals
#                   tds :     0 :     1 :  None : False : False : PositiveReals
#                   tss :     0 :     1 :  None : False : False : PositiveReals
#
#       Objectives:
#         None
#
#       Constraints:
#         None
#     Block fs.unit.properties_treated[0.0]
#
#       Variables:
#         flow_mass_comp : Mass flowrate of each component
#             Size=12, Index=fs.properties.component_list, Units=kg/s
#             Key       : Lower : Value : Upper : Fixed : Stale : Domain
#                   H2O :     0 :     1 :  None : False : False : PositiveReals
#                 boron :     0 :     1 :  None : False : False : PositiveReals
#               bromide :     0 :     1 :  None : False : False : PositiveReals
#               calcium :     0 :     1 :  None : False : False : PositiveReals
#              chloride :     0 :     1 :  None : False : False : PositiveReals
#             magnesium :     0 :     1 :  None : False : False : PositiveReals
#             potassium :     0 :     1 :  None : False : False : PositiveReals
#                sodium :     0 :     1 :  None : False : False : PositiveReals
#             strontium :     0 :     1 :  None : False : False : PositiveReals
#               sulfate :     0 :     1 :  None : False : False : PositiveReals
#                   tds :     0 :     1 :  None : False : False : PositiveReals
#                   tss :     0 :     1 :  None : False : False : PositiveReals
#
#       Objectives:
#         None
#
#       Constraints:
#         None
# None

# %% [markdown]
# ## Step 3: Set the operating conditions of the unit model
# Specify the feed conditions and unit model variables such that the degrees of freedom are zero. Default scaling should also be set for the flow rate to ensure the model is well-scaled.

# %%
print("DOF before specifying:", degrees_of_freedom(m.fs))

# --- load & FIX zero-order params from DB (removals, energy intensity, recovery, etc.) ---
# use_default_removal=True will fix any missing removals to a small default instead of leaving them free
m.fs.unit.load_parameters_from_database(use_default_removal=True)

# --- specify inlet mass flows (one per component) ---
pin = m.fs.unit.properties_in[0]

pin.flow_mass_comp["H2O"].fix(1.000)  # 1 kg/s water
pin.flow_mass_comp["tss"].fix(0.500)  # 0.1 kg/s TSS

t0 = 0.0
pint  = m.fs.unit.properties_in[t0].flow_mass_comp
pout = m.fs.unit.properties_treated[t0].flow_mass_comp

print("inlet tss =", float(pint["tss"].value))
print("treated tss =", float(pout["tss"].value))

# list all components + values (so we see what's actually in the state block)
comps = list(m.fs.properties.component_list)
vals_in  = {c: float(pint[c].value)  for c in comps}
vals_out = {c: float(pout[c].value) for c in comps}
print("components:", comps)
print("in:",  vals_in)
print("out:", vals_out)


# for solutes
for s in m.fs.properties.solute_set:
    pin.flow_mass_comp[s].fix(1e-6)

# --- UV operating inputs ---
m.fs.unit.uv_transmittance_in[0].fix(0.85)  # fraction (0–1)
m.fs.unit.uv_reduced_equivalent_dose[0].fix(40.0 * pyunits.mJ/pyunits.cm**2)  # typical 40 mJ/cm^2

print("DOF after spec:", degrees_of_freedom(m.fs))  # should be 0
# Out:
# DOF before specifying: 24
# inlet tss = 0.5
# treated tss = 1.0
# components: ['H2O', 'boron', 'bromide', 'calcium', 'chloride', 'magnesium', 'potassium', 'sodium', 'strontium', 'sulfate', 'tds', 'tss']
# in: {'H2O': 1.0, 'boron': 1.0, 'bromide': 1.0, 'calcium': 1.0, 'chloride': 1.0, 'magnesium': 1.0, 'potassium': 1.0, 'sodium': 1.0, 'strontium': 1.0, 'sulfate': 1.0, 'tds': 1.0, 'tss': 0.5}
# out: {'H2O': 1.0, 'boron': 1.0, 'bromide': 1.0, 'calcium': 1.0, 'chloride': 1.0, 'magnesium': 1.0, 'potassium': 1.0, 'sodium': 1.0, 'strontium': 1.0, 'sulfate': 1.0, 'tds': 1.0, 'tss': 1.0}
# DOF after spec: 0

# %% [markdown]
# ## Step 4: Solve the flowsheet and display results

# %%
# Check that units are consistent
assert_units_consistent(m) 

# Check that the degrees of freedom are what we expect
assert (
    degrees_of_freedom(m) == 0
)  

solver = get_solver()
results = solver.solve(m, tee=False)

# Check that the solver finds an optimal solution
assert_optimal_termination(results)

# Display results
print("second display")
m.fs.unit.display()
# Out:
# second display
# Block fs.unit
#
#   Variables:
#     _flow_mass_comp_inlet_ref : Size=12, Index=fs._time*fs.properties.component_list, ReferenceTo=fs.unit.properties_in[...].component('flow_mass_comp')[...]
#         Key                : Lower : Value : Upper : Fixed : Stale : Domain
#               (0.0, 'H2O') :     0 :   1.0 :  None :  True :  True : PositiveReals
#             (0.0, 'boron') :     0 : 1e-06 :  None :  True :  True : PositiveReals
#           (0.0, 'bromide') :     0 : 1e-06 :  None :  True :  True : PositiveReals
#           (0.0, 'calcium') :     0 : 1e-06 :  None :  True :  True : PositiveReals
#          (0.0, 'chloride') :     0 : 1e-06 :  None :  True :  True : PositiveReals
#         (0.0, 'magnesium') :     0 : 1e-06 :  None :  True :  True : PositiveReals
#         (0.0, 'potassium') :     0 : 1e-06 :  None :  True :  True : PositiveReals
#            (0.0, 'sodium') :     0 : 1e-06 :  None :  True :  True : PositiveReals
#         (0.0, 'strontium') :     0 : 1e-06 :  None :  True :  True : PositiveReals
#           (0.0, 'sulfate') :     0 : 1e-06 :  None :  True :  True : PositiveReals
#               (0.0, 'tds') :     0 : 1e-06 :  None :  True :  True : PositiveReals
#               (0.0, 'tss') :     0 : 1e-06 :  None :  True :  True : PositiveReals
#     _flow_mass_comp_treated_ref : Size=12, Index=fs._time*fs.properties.component_list, ReferenceTo=fs.unit.properties_treated[...].component('flow_mass_comp')[...]
#         Key                : Lower : Value                 : Upper : Fixed : Stale : Domain
#               (0.0, 'H2O') :     0 :                   1.0 :  None : False : False : PositiveReals
#             (0.0, 'boron') :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#           (0.0, 'bromide') :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#           (0.0, 'calcium') :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#          (0.0, 'chloride') :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#         (0.0, 'magnesium') :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#         (0.0, 'potassium') :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#            (0.0, 'sodium') :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#         (0.0, 'strontium') :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#           (0.0, 'sulfate') :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#               (0.0, 'tds') :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#               (0.0, 'tss') :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#     recovery_frac_mass_H2O : Mass recovery fraction of water in the treated stream
#         Size=1, Index=fs._time, Units=dimensionless
#         Key : Lower : Value : Upper     : Fixed : Stale : Domain
#         0.0 :   0.0 :     1 : 1.0000001 :  True :  True : NonNegativeReals
#     removal_frac_mass_comp : Solute removal fraction on a mass basis
#         Size=11, Index=fs._time*fs.properties.solute_set, Units=dimensionless
#         Key                : Lower : Value : Upper : Fixed : Stale : Domain
#             (0.0, 'boron') :     0 :   0.0 :  None :  True :  True : NonNegativeReals
#           (0.0, 'bromide') :     0 :   0.0 :  None :  True :  True : NonNegativeReals
#           (0.0, 'calcium') :     0 :   0.0 :  None :  True :  True : NonNegativeReals
#          (0.0, 'chloride') :     0 :   0.0 :  None :  True :  True : NonNegativeReals
#         (0.0, 'magnesium') :     0 :   0.0 :  None :  True :  True : NonNegativeReals
#         (0.0, 'potassium') :     0 :   0.0 :  None :  True :  True : NonNegativeReals
#            (0.0, 'sodium') :     0 :   0.0 :  None :  True :  True : NonNegativeReals
#         (0.0, 'strontium') :     0 :   0.0 :  None :  True :  True : NonNegativeReals
#           (0.0, 'sulfate') :     0 :   0.0 :  None :  True :  True : NonNegativeReals
#               (0.0, 'tds') :     0 :   0.0 :  None :  True :  True : NonNegativeReals
#               (0.0, 'tss') :     0 :   0.0 :  None :  True :  True : NonNegativeReals
#     electricity : Electricity consumption of unit
#         Size=1, Index=fs._time, Units=kW
#         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#         0.0 :     0 : 0.3600039599999997 :  None : False : False :  Reals
#     energy_electric_flow_vol_inlet : Electricity intensity with respect to inlet flowrate of unit
#         Size=1, Index=None, Units=kWh/m**3
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :  None :   0.1 :  None :  True :  True :  Reals
#     uv_reduced_equivalent_dose : Reduced equivalent dosage
#         Size=1, Index=fs._time, Units=mJ/cm**2
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :  None :  40.0 :  None :  True :  True :  Reals
#     uv_transmittance_in : UV transmittance of solution at UV reactor inlet
#         Size=1, Index=fs._time, Units=dimensionless
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#         0.0 :  None :  0.85 :  None :  True :  True :  Reals
#
#   Objectives:
#     None
#
#   Constraints:
#     water_recovery_equation : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :  0.0 :   0.0
#     solute_treated_equation : Size=11
#         Key                : Lower : Body                  : Upper
#             (0.0, 'boron') :   0.0 : 2.752857078576476e-21 :   0.0
#           (0.0, 'bromide') :   0.0 : 2.752857078576476e-21 :   0.0
#           (0.0, 'calcium') :   0.0 : 2.752857078576476e-21 :   0.0
#          (0.0, 'chloride') :   0.0 : 2.752857078576476e-21 :   0.0
#         (0.0, 'magnesium') :   0.0 : 2.752857078576476e-21 :   0.0
#         (0.0, 'potassium') :   0.0 : 2.752857078576476e-21 :   0.0
#            (0.0, 'sodium') :   0.0 : 2.752857078576476e-21 :   0.0
#         (0.0, 'strontium') :   0.0 : 2.752857078576476e-21 :   0.0
#           (0.0, 'sulfate') :   0.0 : 2.752857078576476e-21 :   0.0
#               (0.0, 'tds') :   0.0 : 2.752857078576476e-21 :   0.0
#               (0.0, 'tss') :   0.0 : 2.752857078576476e-21 :   0.0
#     electricity_consumption : Size=1
#         Key : Lower : Body : Upper
#         0.0 :   0.0 :  0.0 :   0.0
#
#   Blocks:
#     Block fs.unit.properties_in[0.0]
#
#       Variables:
#         flow_mass_comp : Mass flowrate of each component
#             Size=12, Index=fs.properties.component_list, Units=kg/s
#             Key       : Lower : Value : Upper : Fixed : Stale : Domain
#                   H2O :     0 :   1.0 :  None :  True :  True : PositiveReals
#                 boron :     0 : 1e-06 :  None :  True :  True : PositiveReals
#               bromide :     0 : 1e-06 :  None :  True :  True : PositiveReals
#               calcium :     0 : 1e-06 :  None :  True :  True : PositiveReals
#              chloride :     0 : 1e-06 :  None :  True :  True : PositiveReals
#             magnesium :     0 : 1e-06 :  None :  True :  True : PositiveReals
#             potassium :     0 : 1e-06 :  None :  True :  True : PositiveReals
#                sodium :     0 : 1e-06 :  None :  True :  True : PositiveReals
#             strontium :     0 : 1e-06 :  None :  True :  True : PositiveReals
#               sulfate :     0 : 1e-06 :  None :  True :  True : PositiveReals
#                   tds :     0 : 1e-06 :  None :  True :  True : PositiveReals
#                   tss :     0 : 1e-06 :  None :  True :  True : PositiveReals
#
#       Objectives:
#         None
#
#       Constraints:
#         None
#     Block fs.unit.properties_treated[0.0]
#
#       Variables:
#         flow_mass_comp : Mass flowrate of each component
#             Size=12, Index=fs.properties.component_list, Units=kg/s
#             Key       : Lower : Value                 : Upper : Fixed : Stale : Domain
#                   H2O :     0 :                   1.0 :  None : False : False : PositiveReals
#                 boron :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#               bromide :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#               calcium :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#              chloride :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#             magnesium :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#             potassium :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#                sodium :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#             strontium :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#               sulfate :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#                   tds :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#                   tss :     0 : 9.999999999999972e-07 :  None : False : False : PositiveReals
#
#       Objectives:
#         None
#
#       Constraints:
#         None

# %%
print("treated tss =", float(pout["tss"].value))
# Out:
# treated tss = 9.999999999999972e-07
